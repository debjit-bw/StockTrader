# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, LSTM, Reshape, Concatenate, Input, Lambda
from tensorflow import convert_to_tensor
from tensorflow.keras import backend
import numpy as np
backend.set_floatx('float32')

# %%
n1_1 = LSTM(50, return_sequences = True, name = 'n1_1')
n1_2 = LSTM(40, return_sequences = True, name = 'n1_2')
n1_3 = LSTM(40, return_state = True, name = 'n1_3')
n1_d = Dense(25, kernel_initializer = 'glorot_uniform', activation = 'tanh', name = 'n1_d')

# %%
n2_1 = LSTM(50, return_sequences = True, name = 'n2_1')
n2_2 = LSTM(40, return_sequences = True, name = 'n2_2')
n2_3 = LSTM(40, return_state = True, name = 'n2_3')
n2_d = Dense(25, kernel_initializer = 'glorot_uniform', activation = 'tanh', name = 'n2_d')

# %%
s_1 = LSTM(100, return_sequences = True, name = 's_1')
s_2 = LSTM(50, return_sequences = True, name = 's_2')
s_3 = LSTM(40, return_sequences = True, name = 's_3')
s_4 = LSTM(30, return_sequences = True, name = 's_4')
s_5 = LSTM(10, return_sequences = True, name = 's_5')
s_d = Dense(1, kernel_initializer = 'glorot_uniform', activation = 'tanh', name = 's_d')

# %%
def MODEL (Ts, Tn, Tg):
    # Tn: Number of words in each of Ts's news data
    # Ts: Number of stock prices. There are equal number of news data blocks (each containing Tn words)
    # Tg: Dimentionality of the GloVe vectors used
    
    N1 = Input(shape = (Ts, Tn, Tg), batch_size = 1, name = 'N1')
    N2 = Input(shape = (Ts, Tn, Tg), batch_size = 1, name = 'N2')
    S = Input(shape = (Ts), batch_size = 1, name = 'S')
    
    N_1 = Reshape((Ts, Tn, Tg))(N1)
    N_2 = Reshape((Ts, Tn, Tg))(N2)
    S_ = Reshape((Ts, 1))(S)

    sentiment = convert_to_tensor(np.zeros((1, 1, 50)))   #dim0 (batch_size) is super sticky...setting it to 1 (shape[0]) helps
    
    for i in range(Ts):
        var1 = Lambda(lambda N1: N1[:, i, :, :])(N_1)
        var2 = Lambda(lambda N2: N2[:, i, :, :])(N_2)
        
        var1 = Reshape((Tn, Tg))(var1)
        var2 = Reshape((Tn, Tg))(var2)
        
        var1 = n1_1(var1)
        var2 = n2_1(var2)
        
        var1 = n1_2(var1)
        var2 = n2_2(var2)
        
        _, _, var1 = n1_3(var1)
        _, _, var2 = n2_3(var2)
        
        var1 = n1_d(var1)
        var2 = n2_d(var2)
        
        var1 = Reshape((1, 25))(var1)
        var2 = Reshape((1, 25))(var2)
        
        var = Concatenate(axis = 2)([var1, var2])
        
        sentiment = Concatenate(axis= 1)([sentiment, var])
    
    
    sentiment = Lambda(lambda s: s[:, 1:, :])(sentiment)
    sentiment = Reshape((Ts, 50))(sentiment)
    S_ = Reshape((Ts, 1))(S_)
    
    X = Concatenate(axis = 2)([S_, sentiment])    #dims: (Ts, 51)
    
    X = s_1(X)
    X = s_2(X)
    X = s_3(X)
    X = s_4(X)
    X = s_5(X)
    X = s_d(X)
    
    model = Model(inputs = [N1, N2, S], outputs = X)
    
    return model

# %%
model = MODEL(4, 5, 7)
# Out:
# WARNING:tensorflow:Layer concatenate_1 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# N1 (InputLayer)                 [(1, 4, 5, 7)]       0
# __________________________________________________________________________________________________
# N2 (InputLayer)                 [(1, 4, 5, 7)]       0
# __________________________________________________________________________________________________
# reshape (Reshape)               (1, 4, 5, 7)         0           N1[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (1, 4, 5, 7)         0           N2[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (1, 5, 7)            0           reshape[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (1, 5, 7)            0           reshape_1[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (1, 5, 7)            0           lambda[0][0]
# __________________________________________________________________________________________________
# reshape_4 (Reshape)             (1, 5, 7)            0           lambda_1[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (1, 5, 7)            0           reshape[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (1, 5, 7)            0           reshape_1[0][0]
# __________________________________________________________________________________________________
# n1_1 (LSTM)                     (1, 5, 50)           11600       reshape_3[0][0]
#                                                                  reshape_7[0][0]
#                                                                  reshape_11[0][0]
#                                                                  reshape_15[0][0]
# __________________________________________________________________________________________________
# n2_1 (LSTM)                     (1, 5, 50)           11600       reshape_4[0][0]
#                                                                  reshape_8[0][0]
#                                                                  reshape_12[0][0]
#                                                                  reshape_16[0][0]
# __________________________________________________________________________________________________
# reshape_7 (Reshape)             (1, 5, 7)            0           lambda_2[0][0]
# __________________________________________________________________________________________________
# reshape_8 (Reshape)             (1, 5, 7)            0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (1, 5, 7)            0           reshape[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (1, 5, 7)            0           reshape_1[0][0]
# __________________________________________________________________________________________________
# n1_2 (LSTM)                     (1, 5, 40)           14560       n1_1[0][0]
#                                                                  n1_1[1][0]
#                                                                  n1_1[2][0]
#                                                                  n1_1[3][0]
# __________________________________________________________________________________________________
# n2_2 (LSTM)                     (1, 5, 40)           14560       n2_1[0][0]
#                                                                  n2_1[1][0]
#                                                                  n2_1[2][0]
#                                                                  n2_1[3][0]
# __________________________________________________________________________________________________
# reshape_11 (Reshape)            (1, 5, 7)            0           lambda_4[0][0]
# __________________________________________________________________________________________________
# reshape_12 (Reshape)            (1, 5, 7)            0           lambda_5[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (1, 5, 7)            0           reshape[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (1, 5, 7)            0           reshape_1[0][0]
# __________________________________________________________________________________________________
# n1_3 (LSTM)                     [(1, 40), (1, 40), ( 12960       n1_2[0][0]
#                                                                  n1_2[1][0]
#                                                                  n1_2[2][0]
#                                                                  n1_2[3][0]
# __________________________________________________________________________________________________
# n2_3 (LSTM)                     [(1, 40), (1, 40), ( 12960       n2_2[0][0]
#                                                                  n2_2[1][0]
#                                                                  n2_2[2][0]
#                                                                  n2_2[3][0]
# __________________________________________________________________________________________________
# reshape_15 (Reshape)            (1, 5, 7)            0           lambda_6[0][0]
# __________________________________________________________________________________________________
# reshape_16 (Reshape)            (1, 5, 7)            0           lambda_7[0][0]
# __________________________________________________________________________________________________
# n1_d (Dense)                    (1, 25)              1025        n1_3[0][2]
#                                                                  n1_3[1][2]
#                                                                  n1_3[2][2]
#                                                                  n1_3[3][2]
# __________________________________________________________________________________________________
# n2_d (Dense)                    (1, 25)              1025        n2_3[0][2]
#                                                                  n2_3[1][2]
#                                                                  n2_3[2][2]
#                                                                  n2_3[3][2]
# __________________________________________________________________________________________________
# reshape_5 (Reshape)             (1, 1, 25)           0           n1_d[0][0]
# __________________________________________________________________________________________________
# reshape_6 (Reshape)             (1, 1, 25)           0           n2_d[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (1, 1, 50)           0           reshape_5[0][0]
#                                                                  reshape_6[0][0]
# __________________________________________________________________________________________________
# reshape_9 (Reshape)             (1, 1, 25)           0           n1_d[1][0]
# __________________________________________________________________________________________________
# reshape_10 (Reshape)            (1, 1, 25)           0           n2_d[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat (TensorFlowO [(1, 2, 50)]         0           concatenate[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (1, 1, 50)           0           reshape_9[0][0]
#                                                                  reshape_10[0][0]
# __________________________________________________________________________________________________
# reshape_13 (Reshape)            (1, 1, 25)           0           n1_d[2][0]
# __________________________________________________________________________________________________
# reshape_14 (Reshape)            (1, 1, 25)           0           n2_d[2][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (1, 3, 50)           0           tf_op_layer_concat[0][0]
#                                                                  concatenate_2[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (1, 1, 50)           0           reshape_13[0][0]
#                                                                  reshape_14[0][0]
# __________________________________________________________________________________________________
# reshape_17 (Reshape)            (1, 1, 25)           0           n1_d[3][0]
# __________________________________________________________________________________________________
# reshape_18 (Reshape)            (1, 1, 25)           0           n2_d[3][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (1, 4, 50)           0           concatenate_3[0][0]
#                                                                  concatenate_4[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (1, 1, 50)           0           reshape_17[0][0]
#                                                                  reshape_18[0][0]
# __________________________________________________________________________________________________
# S (InputLayer)                  [(1, 4)]             0
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (1, 5, 50)           0           concatenate_5[0][0]
#                                                                  concatenate_6[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (1, 4, 1)            0           S[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (1, 4, 50)           0           concatenate_7[0][0]
# __________________________________________________________________________________________________
# reshape_20 (Reshape)            (1, 4, 1)            0           reshape_2[0][0]
# __________________________________________________________________________________________________
# reshape_19 (Reshape)            (1, 4, 50)           0           lambda_8[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (1, 4, 51)           0           reshape_20[0][0]
#                                                                  reshape_19[0][0]
# __________________________________________________________________________________________________
# s_1 (LSTM)                      (1, 4, 100)          60800       concatenate_8[0][0]
# __________________________________________________________________________________________________
# s_2 (LSTM)                      (1, 4, 50)           30200       s_1[0][0]
# __________________________________________________________________________________________________
# s_3 (LSTM)                      (1, 4, 40)           14560       s_2[0][0]
# __________________________________________________________________________________________________
# s_4 (LSTM)                      (1, 4, 30)           8520        s_3[0][0]
# __________________________________________________________________________________________________
# s_5 (LSTM)                      (1, 4, 10)           1640        s_4[0][0]
# __________________________________________________________________________________________________
# s_d (Dense)                     (1, 4, 1)            11          s_5[0][0]
# ==================================================================================================
# Total params: 196,021
# Trainable params: 196,021
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(loss = 'mse', metrics = ['accuracy'])
